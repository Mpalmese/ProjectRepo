# %%
import pandas as pd
import numpy as np

# %%
path = "../../U.S. Released Movies_ 1972-2016.csv"
movies = pd.read_csv(path, encoding='latin1')

# %%
movies.head()
# Out:
#                       Title  IMDb Rating  Runtime (mins)    Year  \
# 0              Pulp Fiction          8.9           154.0  1994.0
# 1  The Amazing Spider-Man 2          6.6           142.0  2014.0
# 2  The Shawshank Redemption          9.3           142.0  1994.0
# 3                 Star Wars          8.6           121.0  1977.0
# 4        Back to the Future          8.5           116.0  1985.0
#
#                                Genres  Num Votes Release Date  \
# 0                        Crime, Drama  1607823.0    5/21/1994
# 1           Action, Adventure, Sci-Fi   381550.0    4/10/2014
# 2                               Drama  2057262.0    9/10/1994
# 3  Action, Adventure, Fantasy, Sci-Fi  1102354.0    5/25/1977
# 4           Adventure, Comedy, Sci-Fi   915281.0     7/3/1985
#
#            Directors
# 0  Quentin Tarantino
# 1          Marc Webb
# 2     Frank Darabont
# 3       George Lucas
# 4    Robert Zemeckis

# %%
movies = movies[['Title','IMDb Rating','Runtime (mins)', 'Year', 'Genres', 'Num Votes', 'Release Date', 'Directors']]
movies.head()
# Out:
#                       Title  IMDb Rating  Runtime (mins)    Year  \
# 0              Pulp Fiction          8.9           154.0  1994.0
# 1  The Amazing Spider-Man 2          6.6           142.0  2014.0
# 2  The Shawshank Redemption          9.3           142.0  1994.0
# 3                 Star Wars          8.6           121.0  1977.0
# 4        Back to the Future          8.5           116.0  1985.0
#
#                                Genres  Num Votes Release Date  \
# 0                        Crime, Drama  1607823.0    5/21/1994
# 1           Action, Adventure, Sci-Fi   381550.0    4/10/2014
# 2                               Drama  2057262.0    9/10/1994
# 3  Action, Adventure, Fantasy, Sci-Fi  1102354.0    5/25/1977
# 4           Adventure, Comedy, Sci-Fi   915281.0     7/3/1985
#
#            Directors
# 0  Quentin Tarantino
# 1          Marc Webb
# 2     Frank Darabont
# 3       George Lucas
# 4    Robert Zemeckis

# %%
movies.dropna()
# Out:
#                                                   Title  IMDb Rating  \
# 0                                          Pulp Fiction          8.9
# 1                              The Amazing Spider-Man 2          6.6
# 2                              The Shawshank Redemption          9.3
# 3                                             Star Wars          8.6
# 4                                    Back to the Future          8.5
# 5                                    The Breakfast Club          7.9
# 6                                           The Goonies          7.8
# 7                              The Silence of the Lambs          8.6
# 8                                         Jurassic Park          8.1
# 9                                         The Lion King          8.5
# 10                                                Se7en          8.6
# 11                                            Toy Story          8.3
# 12                                     The Big Lebowski          8.1
# ...

# %%
years = movies['Year']

# %%
count = 0
for x in years:
    if x >= 2010:
        count += 1

# %%
count
# Out:
# 1593
